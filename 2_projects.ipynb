# %%
import requests
from bs4 import BeautifulSoup

import time 
import pandas as pd

# %%
url = 'https://search.dcinside.com/post/p/{}/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90'

for page in range(1,10): 
    print(url.format(page))
# Out:
# https://search.dcinside.com/post/p/1/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90
# https://search.dcinside.com/post/p/2/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90
# https://search.dcinside.com/post/p/3/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90
# https://search.dcinside.com/post/p/4/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90
# https://search.dcinside.com/post/p/5/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90
# https://search.dcinside.com/post/p/6/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90
# https://search.dcinside.com/post/p/7/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90
# https://search.dcinside.com/post/p/8/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90
# https://search.dcinside.com/post/p/9/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90

# %%
response = requests.get(url.format(1))

html = response.text

soup = BeautifulSoup(html, 'lxml')

print(soup)
# Out:
# <!DOCTYPE html>
# <html class="darkmode" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="kr" name="content-language"/>
# <meta content="8_SyZg2Wg3LNnCmFXzETp7ld4yjZB8ny17m8QsYsLwk" name="google-site-verification"/>
# <meta content="디시인사이드" name="author"/>
# <meta content="디시인사이드 검색결과" name="title"/>
# <meta content="디시인사이드 검색결과" name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="디시인사이드 검색결과" property="og:title"/>
# <meta content="디시인사이드 검색결과" property="og:description"/>
# <meta content="https://nstatic.dcinside.com/dc/w/images/descrip_img.png" property="og:image"/>
# <meta content="https://www.dcinside.com/" property="og:url"/>
# <title>디시인사이드 검색결과</title>
# <!--[if IE 7]>
# 	<link rel="stylesheet" type="text/css" href="https://nstatic.dcinside.com/dc/w/css/ie7.css"/>
# 	<![endif]-->
# <script src="https://nstatic.dcinside.com/dgn/gallery/js/cross_domain.js" type="text/javascript"></script>
# <!--[if lt IE 9]>
# 	<script src="https://nstatic.dcinside.com/dgn/gallery/js/jquery-1.7.2.min.js"></script>
# 	<![endif]-->
# <!--[if gte IE 9]>
# 	<script src="https://nstatic.dcinside.com/dgn/gallery/js/jquery-3.2.1.min.js"></script>
# 	<![endif]-->
# <!--[if !IE]> -->
# <script src="https://nstatic.dcinside.com/dgn/gallery/js/jquery-3.2.1.min.js"></script>
# <!-- <![endif]-->
# <script src="https://nstatic.dcinside.com/dgn/gallery/js/jquery.tmpl.min.js" type="text/javascript"></script>
# <script src="https://nstatic.dcinside.com/dgn/gallery/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/_js/jquery/jquery.paging.js" type="text/javascript"></script>
# <script src="/_js/jquery/jquery.validate.js" type="text/javascript"></script>
# <script src="/_js/jquery/jquery.placeholder.min.js" type="text/javascript"></script>
# <script src="/_js/jquery/jquery.tmpl.min.js" type="text/javascript"></script>
# <script src="/_js/ctr_cookie.min.js" type="text/javascript"></script>
# <script src="/_js/common.js?v=241105" type="text/javascript"></script>
# <script src="/_js/common_json.js?v=241105" type="text/javascript"></script>
# <script src="/_js/navigation.js" type="text/javascript"></script>
# <script src="/_js/click_log.js" type="text/javascript"></script>
# <script src="https://gall.dcinside.com/_js/globalSearch.js?220331" type="text/javascript"></script>
# <script src="https://gall.dcinside.com/_js/crossDomainStorage.js?1" type="text/javascript"></script>
# <script src="https://gall.dcinside.com/_js/lately_visit_v1.js?3" type="text/javascript"></script>
# <script src="https://gall.dcinside.com/_js/favorite_v1.js?3" type="text/javascript"></script>
# <script src="https://gall.dcinside.com/_js/alarm_polling.js?2208" type="text/javascript"></script>
# <script src="https://gall.dcinside.com/_js/gallery_right_login.js?2208" type="text/javascript"></script>
# <script type="text/javascript">
# 		document.domain = "dcinside.com";
# 	</script>
# <link href="https://nstatic.dcinside.com/dc/w/images/logo_icon.ico" rel="shortcut icon"/>
# <link href="https://nstatic.dcinside.com/dc/w/css/reset.css?v=2" rel="stylesheet" type="text/css"/>
# <link href="https://nstatic.dcinside.com/dc/w/css/common.css?250123-1" rel="stylesheet" type="text/css"/>
# <link href="https://nstatic.dcinside.com/dc/w/css/contents.css?v=220614" rel="stylesheet" type="text/css"/>
# <link href="https://nstatic.dcinside.com/dc/w/css/popup.css?2203" rel="stylesheet" type="text/css"/>
# <script src="https://nstatic.dcinside.com/dc/w/js/html5shiv.min.js" type="text/javascript"></script>
# <!--[if IE 7]>
# 		<Link Rel="Stylesheet" Type="Text/Css" Href="Https://Nstatic.Dcinside.Com/Dc/W/Css/Ie7.Css"/>
# 	<![Endif]-->
# <style type="text/css">
# 	.search_keylayer { left: 340px; }
# 	</style>
# <script type="text/javascript">
# 		//우측 상단 더보기
# 		function moreView1()
# 		{
# 			if(document.getElementById("gnb_layer2").style.display =="none")
# 			{
# 				document.getElementById("gnb_layer2").style.display ="block";
# 			}
# 			else {
# 				document.getElementById("gnb_layer2").style.display ="none";
# 			}
# 		}
#
# 	</script>
# </head>
# <body>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-5149721-69', 'auto');
#   ga('require', 'displayfeatures');
#   ga('send', 'pageview');
#
# </script>
# <!--스킵 내비게이션-->
# <div class="skip">
# <a href="#search_wrap"><span>통합검색 바로가기</span></a>
# <a href="#container"><span>본문영역 바로가기</span></a>
# </div>
# <!-- //스킵 내비게이션-->
# <div class="dcwrap width1160 integrate_schwrap" id="top">
# <!-- 상단 -->
# <header class="dcheader">
# <div class="dchead">
# <!-- 로고영역 -->
# <h1 class="dc_logo">
# <a href="https://www.dcinside.com/">
# <img alt="디시인사이드" class="logo_img" src="https://nstatic.dcinside.com/dc/w/images/dcin_logo.png"/> </a>
# <a href="https://search.dcinside.com/">
# <img alt="통합검색" class="logo_img2" src="https://nstatic.dcinside.com/dc/w/images/tit_integrate_search.png"/> </a>
# </h1>
# <!-- //로고영역 -->
# <div class="wrap_search" id="search_wrap">
# <h2 class="blind">갤러리 검색</h2>
# <!-- 갤러리 통합검색 -->
# <form action="" data-tab="post" id="searchform" method="get" name="topSearchForm" onsubmit="return globalSearch(this);">
# <fieldset>
# <legend class="blind">통합검색</legend>
# <div class="top_search clear">
# <div class="inner_search">
# <input accesskey="f" autocomplete="off" class="in_keyword" id="gn_top_search_0" name="search" onfocus="show_search_keywords(this)" placeholder="갤러리 &amp; 통합검색" style="ime-mode:active;" tabindex="1" title="검색어 입력" type="text" value="편의점"/>
# </div>
# <button class="sp_img bnt_search btn_globalSearch"><span class="blind">검색</span></button>
# <button class="btn_visit" onclick="openLately()" type="button">최근 방문</button>
# </div>
# </fieldset>
# </form>
# <!-- //갤러리 통합검색 -->
# <!-- 최근방문 레이어 -->
# <div class="pop_wrap type2" id="visit_history_lyr" style="left:0;top:45px;display:none;">
# <div class="pop_content visit bookmk">
# <div class="visitab_box">
# <button class="gallTab on" onclick="tabLately('gall')" type="button">최근 방문</button>
# <button class="favTab" onclick="tabLately('fav')" type="button">즐겨찾기</button>
# </div>
# <div class="tab_content">
# <!-- 최근방문 갤러리 리스트 -->
# <div id="gall_div">
# <p class="gall_msg empty_box" style="display:none">최근 방문 갤러리가 없습니다.</p>
# <ul class="pop_visit_list gall clear" style="display:block"></ul>
# <script id="lyr_lately_galls-tmpl" type="text/x-jquery-tmpl">
#                         <li class="lately_gall gall_${id}" style="display:none;">
#                           <a href="https://${link}" class="lately_log" section="${id}">${name}</a>{{if type == 'MI'}}<em class="icon_mini">미니갤러리</em>{{/if}}
#                           <button type="button" class="btn_del" style="outline:" data-id="${id}"><span class="blind" >삭제</span><em class="sp_img icon_del"></em></button>
#                         </li>
# 					  </script>
# </div>
# <!-- 즐겨찾기 리스트 -->
# <div id="fav_div">
# <p class="empty_box"><a href="https://sign.dcinside.com/login?s_url=https%3A%2F%2Fsearch.dcinside.com%2Fpost%2Fp%2F1%2Fsort%2Flatest%2Fq%2F.ED.8E.B8.EC.9D.98.EC.A0.90"><span>로그인</span> 후 이용 가능합니다.</a></p>
# <script id="lyr_lately_favs-tmpl" type="text/x-jquery-tmpl">
# 						<li class ="lately_gall fav_${code_id}" style="display:none;"><a href="https://gall.dcinside.com/{{if type == 'MI'}}mini/{{/if}}${code_id}" class="">${name}</a>{{if type == 'MI'}}<em class="icon_mini">미니갤러리</em>{{else type == 'M'}}<em class="icon_minor">ⓜ</em>{{/if}}</li>
# 					  </script>
# </div>
# </div>
# <div class="paging_btnbox">
# <div class="inner">
# <button class="btn_prev" id="lately_prev" type="button"><span class="blind">이전</span><em class="sp_img icon_prev"></em></button>
# <div class="page_num page_gall">
# <strong class="now_num">1</strong>/<span class="total_num">1</span>
# </div>
# <div class="page_num page_fav" style="display:none;">
# <strong class="now_num">1</strong>/<span class="total_num">1</span>
# </div>
# <button class="btn_next" id="lately_next" type="button"><span class="blind">다음</span><em class="sp_img icon_next"></em></button>
# </div>
# <button class="list_modi page_fav" onclick="myFavorite('185')" style="display:none;" type="button">편집</button>
# <!-- div class="pop_wrap type3" id = "my_favorite" style="right:12px;top:23px;display:none"></div-->
# </div>
# </div>
# </div>
# <!-- //최근방문 -->
# <!-- 검색 자동완성 레이어-->
# <div class="top_banner">
# </div>
# <!--자동완성 레어이 : display:block -->
# <!--div class="auto_wordwrap" style="left:0;top:45px;display:none">
# 	  </div-->
# <!-- //검색 자동완성 레이어 -->
# </div>
# <div class="area_links clear">
# <ul class="fl clear">
# <li><a href="https://gall.dcinside.com/">갤러리</a></li>
# <li><a href="https://gall.dcinside.com/m">마이너갤</a></li>
# <li><a href="https://gall.dcinside.com/n">미니갤</a></li>
# <li><a href="https://gall.dcinside.com/p">인물갤</a></li>
# <li><a href="https://gallog.dcinside.com">갤로그</a></li>
# <li><a href="https://dctrend.ai/news/trend">디시트렌드</a></li>
# <li><a href="https://dcnewsj.joins.com/">디시뉴스</a></li>
# <li><a href="https://h5.dcinside.com/game/main">디시게임</a></li>
# <li><a href="https://event.dcinside.com">이벤트</a></li>
# <li><a href="https://mall.dcinside.com/?from=A08">디시콘</a></li>
# <li><a class="btn_top_loginout" href="https://sign.dcinside.com/login?s_url=https://search.dcinside.com/combine/q/.ED.8E.B8.EC.9D.98.EC.A0.90" target="_top">로그인</a></li>
# </ul>
# <div class="fl darkmodebox">
# <a class="darkonoff" href="javascript:;" onclick="darkmode()"><em class="sp_img icon_tdark"></em>야간모드</a>
# <div class="pop_tipbox join_tip dark" onclick="$(this).hide();used_darkmode();" style="top:25px;left:-35px;display:">
# <div class="inner">
# <p class="join_txt">야간 모드를 이용해 보세요</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <!-- //상단 -->
# <!-- GNB -->
# <div class="gnb_bar">
# <nav class="gnb clear">
# <h2 class="blind">GNB</h2>
# <ul class="gnb_list clear">
# <li><a class="" href="https://search.dcinside.com/combine/q/.ED.8E.B8.EC.9D.98.EC.A0.90">통합</a></li>
# <li><a class="" href="https://search.dcinside.com/gallery/q/.ED.8E.B8.EC.9D.98.EC.A0.90">갤러리</a></li>
# <li><a class="" href="https://search.dcinside.com/news/q/.ED.8E.B8.EC.9D.98.EC.A0.90">뉴스</a></li>
# <li><a class="" href="https://search.dcinside.com/movie/q/.ED.8E.B8.EC.9D.98.EC.A0.90">동영상</a></li>
# <li><a class="on" href="https://search.dcinside.com/post/q/.ED.8E.B8.EC.9D.98.EC.A0.90">게시물</a></li>
# </ul>
# <!-- 어제 게시글,댓글 등록 -->
# <div class="gall_exposure">
# <div class="posts"><a href="https://gall.dcinside.com/board/lists/?id=dclottery">어제 <em class="num" id="total_content_count"></em> 게시글 등록</a></div>
# <div class="reply"><a href="https://gall.dcinside.com/board/lists/?id=dclottery">어제 <em class="num" id="total_reple_count"></em> 댓글 등록</a></div>
# <div class="gall">총 갤러리 수 <em class="num" id="total_gallery_count"></em></div>
# <div class="ltr"><a href="https://gall.dcinside.com/board/lists/?id=dclottery">디시 로터리 응모</a></div>
# </div>
# <!-- /어제 게시글,댓글 등록 -->
# </nav>
# </div>
# <!-- //GNB -->
# <main class="integrate_sch" id="container">
# <div class="group clear">
# <!-- left_content -->
# <section class="left_content">
# <h2 class="blind">통합검색 왼쪽 컨텐츠 영역</h2>
# <div>
# <ins class="kakao_ad_area" data-ad-height="600" data-ad-unit="DAN-Yy7BdlhGdOZBWriq" data-ad-width="160" style="display:none;"></ins>
# <script async="" src="//t1.daumcdn.net/kas/static/ba.min.js" type="text/javascript"></script>
# </div>
# </section>
# <!-- //left_content -->
# <!-- center_content -->
# <section class="center_content">
# <h2 class="blind">통합검색 가운데 컨텐츠 영역</h2>
# <div class="inner">
# <!-- 파워링크 -->
# <div class="power_link ad_premium">
# </div>
# <!-- //파워링크 -->
# <!-- 게시물 검색결과 -->
# <div class="integrate_cont sch_result result_all">
# <div class="integrate_cont_head clear">
# <h3 class="fl">게시물</h3>
# <div class="btn_sort_box fr">
# <!-- 최순순일때 클래스 new /  정확도일때 accuracy -->
# <button class="btn_sort txt new" onclick="location.href='/post/q/.ED.8E.B8.EC.9D.98.EC.A0.90'">최신순</button>
# <button class="btn_sort txt" onclick="location.href='/post/sort/accuracy/q/.ED.8E.B8.EC.9D.98.EC.A0.90'">정확도순</button>
# <!-- <button class="btn_sort sp_img accuracy"><span class="blind">정확도</span></button> -->
# </div>
# </div>
# <ul class="sch_result_list">
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=cs_new1&amp;no=7037135" target="_blank">이거코리안</a>
# <p class="link_dsc_txt">행복한 하루 보내세요 <b>편의점</b> 갤러리 나링</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=cs_new1" target="_blank">편의점</a><span class="date_time">2025.05.03 00:19</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=crane&amp;no=156" target="_blank">크레인 부기사 한달하고 때려치움....굴삭기 경력쌓으러 런한다..</a>
# <p class="link_dsc_txt">거 보고 맘접기로 함. 나중에 내가 기사달고도 평생 저렇게 땀흘리면서 세팅하고 철수할 자신이 없다.. <b>편의점</b>만 하다가 현장일하니 의욕으론 1주일 밖에 못버티겠더라 내가 책임질 식구들이 있다? -&gt; 식구들만...</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=crane" target="_blank">크레인</a><span class="date_time">2025.05.03 00:18</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=umamusu&amp;no=4533676" target="_blank">나 이타백매고 동네<b>편의점</b>도 잘만 가는데</a>
# <p class="link_dsc_txt">오타쿠인거 온동네사람이 다 알겠다고 엄니가 재밌어해</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=umamusu" target="_blank">우마무스메 프리티 더비</a><span class="date_time">2025.05.03 00:17</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=drama_new3&amp;no=19167704" target="_blank"><b>편의점</b> 식탁 저거 탐나는데????</a>
# <p class="link_dsc_txt">??</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=drama_new3" target="_blank">기타 국내 드라마</a><span class="date_time">2025.05.03 00:16</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mini/board/view/?id=isekaidol&amp;no=4176114" target="_blank">이세돌빵 나오면 동네 <b>편의점</b> 뒤졌다 봐야지</a>
# <p class="link_dsc_txt"></p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mini/board/lists?id=isekaidol" target="_blank">이세계아이돌</a><span class="date_time">2025.05.03 00:15</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=dkslflzkssk&amp;no=746564" target="_blank">주휴수당 검색해보는데 <b>편의점</b> 점주들 겁나 웃기네</a>
# <p class="link_dsc_txt">15시간 이상 근무시켜놓고 주휴수당을 요구하는게 엄청 나쁜짓이라고 생각하는건가ㅋㅋ</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=dkslflzkssk" target="_blank">아이리 칸나</a><span class="date_time">2025.05.03 00:14</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=bluecollar&amp;no=427296" target="_blank">생산직 갤러리 공식 채팅방 오세요</a>
# <p class="link_dsc_txt">#대기업#공기업#공무원#와이고수#와고#백수#흙수저#상하차#노가다#생산직#시설관리#사무직#디시#<b>편의점</b>#알바#배달#마트#아르바이트#제조업#중공업#학생#취준생#총무#회계#경리#경비#보안#이직#면접#채용#쿠팡...</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=bluecollar" target="_blank">생산직</a><span class="date_time">2025.05.03 00:13</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=jungsopd&amp;no=1311918" target="_blank">중소기업 갤러리 공식 채팅방 오세요</a>
# <p class="link_dsc_txt">#대기업#공기업#공무원#와이고수#와고#백수#흙수저#상하차#노가다#생산직#시설관리#사무직#디시#<b>편의점</b>#알바#배달#마트#아르바이트#제조업#중공업#학생#취준생#총무#회계#경리#경비#보안#이직#면접#채용#쿠팡...</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=jungsopd" target="_blank">중소기업</a><span class="date_time">2025.05.03 00:11</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=sff&amp;no=1298241" target="_blank">KT 데쉐에 쓸 유심 찾다가 질문글 신기한거 많은듯...</a>
# <p class="link_dsc_txt"><b>편의점</b> 가면 바로유심 팔지만 가지고 있는 포인트 쓸려고 무배 유심 찾고 있는데 중국산인가 아닌가 코나아이의 제품인가 아닌가 이런 질문글이 유독 많이 보이네;;;;; 근데 제조국은 둘째치고 어느 회사 제품...</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=sff" target="_blank">SFF</a><span class="date_time">2025.05.03 00:10</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=cs_new1&amp;no=7037086" target="_blank">아오 비 오는데 <b>편의점</b>을 왜 쳐 오는 거야</a>
# <p class="link_dsc_txt">다 나가!!!!</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=cs_new1" target="_blank">편의점</a><span class="date_time">2025.05.03 00:09</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=sff&amp;no=1298238" target="_blank"><b>편의점</b> 알바하면서 견적 짜봄</a>
# <p class="link_dsc_txt">한달만 더 일하면 300만원 모이는데 견적 짜봤는데 어때??? 나쁘지 않지?? 저렇게 하니까 310만원 나오더라 폼디 T1 살려다가 나 조립 실패할것 같아서 빅타워 쓰는 애들은 작다고 차별 받고 SFF 변태들에게는...</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=sff" target="_blank">SFF</a><span class="date_time">2025.05.03 00:09</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&amp;no=6740016" target="_blank">오늘 스즈메랑 문단속이 아니라</a>
# <p class="link_dsc_txt">몬스터음료랑 하방 단속 해야겠다 주갤햄들 다들 <b>편의점</b>에서 에너지드링크 1발 장전 ㄱㄱ</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=tenbagger" target="_blank">해외주식</a><span class="date_time">2025.05.03 00:08</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=w_entertainer&amp;no=23851274" target="_blank">헬똥 석촌호수 근처 살면서</a>
# <p class="link_dsc_txt"><b>편의점</b> 좆바 왜하노</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=w_entertainer" target="_blank">여자 연예인</a><span class="date_time">2025.05.03 00:08</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=fantasy_new2&amp;no=7611862" target="_blank"><b>편의점</b>에 조각 케익사러갈까</a>
# <p class="link_dsc_txt">근데 작년 생일에 갔다가 5군대서 안팔아서 울쩍해져가지고 나가기 쉽지않음</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=fantasy_new2" target="_blank">판타지</a><span class="date_time">2025.05.03 00:08</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=genrenovel&amp;no=10351800" target="_blank">내일은 <b>편의점</b> 가서 빵이나 먹어야지</a>
# <p class="link_dsc_txt">씰 모으는 재미가 있네</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=genrenovel" target="_blank">장르소설</a><span class="date_time">2025.05.03 00:02</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=tracenacademy&amp;no=380430" target="_blank"><b>편의점</b>가면 꼭 사는 것</a>
# <p class="link_dsc_txt">갑자기 먹고 싶어진 컵라면 종류별로 몇개 점심시간이면 도시락 참치김밥 롤케이크 정도려나</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=tracenacademy" target="_blank">트레센 학원(우마무스메)</a><span class="date_time">2025.05.03 00:01</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=cs_new1&amp;no=7037021" target="_blank">노동청의 힘을 계승한 자는</a>
# <p class="link_dsc_txt">3년 후면 체불임금을 돌려받을 수 없다 내가 계승한 것도 3년 전이야 하지만 너는 대구 <b>편의점</b>을 시작했다. 우린 임금을 원했고 노동은 동포가 지불했다. 그 값을 치를 방법은 하나 밖에 없다. 나는 여기서 처음...</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=cs_new1" target="_blank">편의점</a><span class="date_time">2025.05.02 23:59</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=creepynuts&amp;no=430" target="_blank">마츠나가 방금 라방ㅋㅋ</a>
# <p class="link_dsc_txt">오쓰- 오쓰- 오쓰- 여러분 좋아하는 돈부리 알려주세요 졸아하는 <b>편의점</b> 아이스크림 알려주세요 그러다가 끔ㅋㅋㅋㅋㅋ</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=creepynuts" target="_blank">크리피넛츠</a><span class="date_time">2025.05.02 23:57</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=cs_new1&amp;no=7036997" target="_blank">탈갤.</a>
# <p class="link_dsc_txt">오늘 엄마한테 가서 더는 못 도와준다고 말하고 <b>편의점</b>이랑 연 끊을거임 ㅅㄱ</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=cs_new1" target="_blank">편의점</a><span class="date_time">2025.05.02 23:56</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=arbeit&amp;no=6513676" target="_blank"><b>편의점</b> 데려갔는데 뭐 살지 한참 고민하는 여자는 걸러라</a>
# <p class="link_dsc_txt">그건 돈보다 시간이 더 소중하다는걸 모르는 멍청한 여자니깐</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=arbeit" target="_blank">아르바이트</a><span class="date_time">2025.05.02 23:55</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=ncdinos&amp;no=8515258" target="_blank">문수구장 주변에 아무것도 없던데</a>
# <p class="link_dsc_txt">카카오지도로 보니 주변에 아무것도 없던데 치킨이랑 술은 어디서 사냐? 꼴 제2구장으로 쓰는 구장이라 임시<b>편의점</b> 빼면 아예 입점된 곳이 없을거고</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=ncdinos" target="_blank">NC 다이노스</a><span class="date_time">2025.05.02 23:53</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=asiaenter&amp;no=973797" target="_blank">치킨먹기는 글렀고</a>
# <p class="link_dsc_txt">이제 <b>편의점</b> 뿐이네 - dc official App</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=asiaenter" target="_blank">아시아엔터</a><span class="date_time">2025.05.02 23:51</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=jungsopd&amp;no=1311904" target="_blank">나 진심으로 궁금한데 너네들 뭐하고 놀아?</a>
# <p class="link_dsc_txt">거 찾느라고 술이랑 여자인데 술도 여자도 솔직히 돈 쎄게 들잖아 제대로 하려면 그냥 맥주나 소주 <b>편의점</b>에서 사서 집에서 족발이랑 같이 먹고 유튜브보면서 그정도임? 평균적인 중소기업 자산이나 소득수준...</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=jungsopd" target="_blank">중소기업</a><span class="date_time">2025.05.02 23:48</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/mgallery/board/view/?id=teamshanghaialice&amp;no=1438858" target="_blank">님들은 <b>편의점</b>에서 계산 중인데 뒷사람이</a>
# <p class="link_dsc_txt">불쑥 와서 담배 이름 외치고 돈 뻗으면 무슨 기분 듬? 본인 아까 한 손님 둘이 그래서 싸울뻔했는데 끼어든 손님 말로는 그냥 대기 하는거라던데 그래서 두분이서 서로 뭐라 하다가 끼어든 손님이 나보고 "내가...</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/mgallery/board/lists?id=teamshanghaialice" target="_blank">상하이앨리스환악단</a><span class="date_time">2025.05.02 23:47</span></p>
# </li>
# <li>
# <a class="tit_txt" href="https://gall.dcinside.com/board/view/?id=bluecollar&amp;no=427255" target="_blank">알바 짤림..</a>
# <p class="link_dsc_txt"><b>편의점</b> 야간알바 하는데 커피머신 있어서 얼음컵만 내돈으로 사서 에스프레소 몇번 먹었는데 사장이 씨씨티비 다 봤다고 절도라고 협박하길래 ㅈㄴ 억울하게 짤림.. - dc official App</p>
# <p class="link_dsc_txt dsc_sub"><a class="sub_txt" href="https://gall.dcinside.com/board/lists?id=bluecollar" target="_blank">생산직</a><span class="date_time">2025.05.02 23:46</span></p>
# </li>
# </ul>
# </div>
# </div>
# <!-- 하단 통합 검색-->
# <div class="integrate_buttom_search">
# <!-- 페이징 -->
# <div class="bottom_paging_box iconpaging" id="dgn_btn_paging"><em>1</em><a href="/post/p/2/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">2</a><a href="/post/p/3/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">3</a><a href="/post/p/4/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">4</a><a href="/post/p/5/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">5</a><a href="/post/p/6/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">6</a><a href="/post/p/7/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">7</a><a href="/post/p/8/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">8</a><a href="/post/p/9/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">9</a><a href="/post/p/10/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">10</a><a class="sp_pagingicon page_next" href="/post/p/11/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">다음</a><a class="sp_pagingicon page_end" href="/post/p/120/sort/latest/q/.ED.8E.B8.EC.9D.98.EC.A0.90">끝</a></div><!-- //페이징 -->
# <form action="https://search.dcinside.com/combine/" method="get" name="bottomSearchForm" onsubmit="return globalSearch(this);">
# <fieldset>
# <legend class="blind">통합검색</legend>
# <div class="buttom_search_wrap clear">
# <div class="bottom_search fl clear">
# <div class="inner_search">
# <input class="in_keyword" name="search" title="검색어 입력" type="text" value="편의점"/>
# </div>
# <button class="sp_img bnt_search btn_globalSearch" type="submit"><span class="blind">검색</span></button>
# </div>
# </div>
# </fieldset>
# </form>
# </div>
# <!-- //하단 통합 검색-->
# </section>
# <!-- right_content -->
# <section class="right_content">
# <h2 class="blind">통합검색 오른쪽 컨텐츠 영역</h2>
# <!-- 다음 검색 -->
# <article>
# <div class="content_box r_only_daum">
# <header class="clear">
# <h3 class="tit fl"><a href="">다음 검색</a></h3>
# <div class="fr">
# <a class="inner_txt" href="https://daum.net">제공 Daum 검색</a><button onclick="$('.daum_tip').show();" type="button"><span class="blind">다음검색이란</span><em class="sp_img icon_tip_open"></em></button>
# </div>
# <div class="pop_tipbox daum_tip" style="left:0px;top:11px;display:none"><!-- 220419 left,top값 수정-->
# <div class="inner">
#                     검색어를 누르면, Daum 검색결과로 이동합니다.
#             	<button class="btn_tipclose" onclick="$('.daum_tip').hide();" type="button"><span class="blind">닫기</span><em class="sp_img icon_tipclose"></em></button>
# </div>
# </div>
# </header>
# <div class="only_daum_area">
# <form>
# <fieldset>
# <legend class="blind">다음 검색</legend>
# <div class="small_searchbox clear">
# <input class="small_in_keyword" onkeydown="javascript:if(event.keyCode==13){searchKaKao();};" title="검색어 입력" type="text"/>
# <input class="origin_keyword" name="origin_keyword" type="hidden" value=""/>
# <button class="btn_iconsearch"><span class="blind" onclick="searchKaKao();">검색</span><em class="sp_img icon_smallsearch"></em></button>
# <button class="bnt_smallsearch" onclick="searchKaKao();" type="submit">다음 검색</button>
# <!-- 검색 자동완성 레이어-->
# <div class="auto_wordwrap small" style="left:-1px;top:28px;display:none"><!--자동완성 레어이 : display:block -->
# <div class="auto_word">
# <div class="word_box">
# <h3 class="blind">실기간 검색결과</h3>
# <ul class="word_list">
# </ul>
# </div>
# </div>
# <div class="word_close"><a class="sp_img btn_close" href="javascript:hideLyr()"><span class="blind">자동완성 레이어 닫기</span></a></div>
# </div>
# <!-- //검색 자동완성 레이어 -->
# </div>
# </fieldset>
# </form>
# <div class="fix_element">
# <a class="fix_txt" href="https://search.daum.net/search?&amp;w=tot&amp;DA=DIK&amp;q=%EB%82%A0%EC%94%A8+%ED%98%84%EC%9C%84%EC%B9%98" target="_blank">날씨</a>
# <a class="fix_txt" href="https://search.daum.net/search?&amp;w=tot&amp;DA=DIK&amp;q=%EC%9A%B4%EC%84%B8" target="_blank">운세</a>
# <a class="fix_txt" href="https://search.daum.net/search?&amp;w=tot&amp;DA=DIK&amp;q=%ED%99%98%EC%9C%A8" target="_blank">환율</a>
# </div>
# </div>
# </div>
# </article>
# <!-- //다음 검색 -->
# <!-- 실시간 베스트 -->
# <article>
# <div class="content_box r_timebest">
# <header>
# <h3 class="tit"><a href="https://gall.dcinside.com/board/lists?id=dcbest">실시간 베스트</a></h3>
# <div class="pageing_box">
# <div class="page_num">
# <strong class="now_num realtimeNum">1</strong>/<span class="total_num realtimeTotal">8</span>
# </div>
# <button class="btn_blueprev" id="realtime_prev" type="button"><span class="blind">이전</span><em class="sp_img icon_blueprev"></em></button>
# <button class="btn_bluenext on" id="realtime_next" type="button"><span class="blind">다음</span><em class="sp_img icon_bluenext"></em></button>
# </div>
# </header>
# <div class="rcont_imgtxt_box">
# <div class="img">
# <div class="rcontimg_box">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327351">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73de882fa11d028311f815e76427ca587580740d4dcef76967833816e8176d545aa6639cf6531721e3b291cb36a3d31bb231ab007f37012a32f81f90ffae4da74eac0ab4e8a922ef574acb70441251e7dd2088a539abca1f3abd2648f" style=""/>
# </span>
# <div class="txt_box">
# <strong>10대 소녀 죽이고 웃던 삼대남, 반성문 내용 보니...‘소름’</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327253">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73fe882fa11d028310673c8c0c405f98f4834dedf82e5137719462c2d3f04f8fafbdad3874ade7aacae100206ba60f6c7bbdeabcc6c2542364b39f8391861fd4f94f502065ef0d4a731714de2fadd72bd008ba3c0da68c4e8c664a4fa72e7db73c767e51c" style=""/>
# </span>
# <div class="txt_box">
# <strong>여자 축구리그 정상화....jpg</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327289">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73de882fa11d028311f815e76427ca587580740d4dcef768b517f060ef70853b23f9876c296440ac47e987544d1d0e540f06ebe8dfd276c1e397e91479ed9f71e21099644fc96a192f9c162d90ac78efaa1f280f63fe50ed68076c975b83e758feda0b92ab1cd5ea0002a6b61" style=""/>
# </span>
# <div class="txt_box">
# <strong>싱글벙글 종교 지도자는 과연 AI로 대체불가능할까?</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327261">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73fe882fa11d028310673c8c0c405f98f4834dedf82e513726b76299b5041c1c289f29412e00627f143b8ab42f83cc582c0aa29aad523730df9b478a5dab443067dec5c73f430bcfb3fbc15d9075c7d5248666d17bbc4cacc545f3a9d8757" style="{" top=""/>
# </span>
# <div class="txt_box">
# <strong>편백이에게 고백하는 만화</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327381">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73fe882fa11d028310673c8c0c405f98f4834dedf82e51375c8ac0bae109522723b1b7d47b3cd94ef7e58e53cd3799c64f931a88746fb8502fe91591dbfcc0747592a42f4eb52c14cb27476a20c97c3ef9ed6144131a3" style=""/>
# </span>
# <div class="txt_box">
# <strong>I.O.I 때는 속옷 갈아입을 시간도 없었다는 청하.jpg</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327428">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73de882fa11d028311f815e76427ca587580740d4dcec768bfaba12276a157a9fc157ac930726e64ae6fdb78d9591c167de1657a3a2dddf3c32c8876262110a67dd44618db210229b0514557e203153b6144d1cf83bf910bd293c3481492b" style=""/>
# </span>
# <div class="txt_box">
# <strong>3일 안에 300번 절정해야 사는 엘프.manhwa</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327259">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73de882fa11d028311f815e76427ca587580740d4dcec768bfaba12276a157a9fc157ac930726e64ae7f1b6819292cb60d31357f3f2ded63b90ba7034d617c42bf338f8c53b8498c5870df3d33c2b3841da1357659b99018b64612808ebe56141b43a960d234681" style=""/>
# </span>
# <div class="txt_box">
# <strong>안싱글벙글 경계선 지능을 겪는 아이들의 상태</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327293">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73ce882fa11d02831cb26081315e58c5fcc516e71e8c6c2b14089abf9cd003350833186d0ebc86cf6a36a83015e1d7298dca3a2284699b5d5b2571eff403e24bbecc5ff58f8a51e2260bd89eefac868" style=""/>
# </span>
# <div class="txt_box">
# <strong>조희대 여중생 사건 유명했구나</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327315">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73fe882fa11d028310673c8c0c405f98f4834dedf82e613701023dba1792947e01026d22b4a292f1d56682d880d4552d204b856518abe1322fd905749fffecbd5e537f6c585773b60deddb5464a940f97844e88c0c858ae7a898be5" style=""/>
# </span>
# <div class="txt_box">
# <strong>나거한 성인 절반, 인플레이션이 뭔지 모른다</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327325">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73de882fa11d028311f815e76427ca587580740d4dcef7696783c9a68cb289004b06630cf63327d77a5298f9e1756a0207a941b82bf4c7a77a1e56e5ed6189474f311c5f0064a2d309bcff832fb8cbe63fae149daab71c0aa" style=""/>
# </span>
# <div class="txt_box">
# <strong>AI 일러스트 사용 의혹 나온 국내 게임(넥슨)</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327339">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73de882fa1bd62531b6b898211a669f8109c0200a5f3aebe5561fc561c99a402623359ccf9f4554423d94ce246fa6528f7162b188e17cf547e787d78662a54d8d" style=""/>
# </span>
# <div class="txt_box">
# <strong>스압) 태국 여행기 3,4</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327327">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73de882fa1bd62531b6b898211a669f8109c0200b5f39eae5350d50faa5adbe4a783eb83f357b0a735c641b8dca3ea172ad86b56e0299c483ae90f21838268410c69e" style=""/>
# </span>
# <div class="txt_box">
# <strong>싱글벙글 어린이날에 대해서 알아보자.araboja</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327321">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73ce882fa11d02831cb26081315e58c5fcc516e71e8c5c2af642632393bcb46181bc3c04e808981cbf4d7a724add90ffd236372f5d5d65a84" style=""/>
# </span>
# <div class="txt_box">
# <strong>아내를 의심해 뒷조사를 부탁한 남자.jpg</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327366">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73fe882fa11d028310673c8c0c405f98f4834dedf82e5137334a38df0ef88334b2ee1429d73fe62e69a75805e78fe14f87b950773f5920efb0a76bc755560" style=""/>
# </span>
# <div class="txt_box">
# <strong>블라)교사 3~5등급이 하면 충분하다.jpg</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327423">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73de882fa1bd62531b6b898211a669f8109c0200a5f3aebe5580bdb7fc3954a7d606dd399ca5e5447ffb468f775f81c597f0552a7ca4a765ee84b" style=""/>
# </span>
# <div class="txt_box">
# <strong>제주도까지 자차로 운전해서 캠핑하고 왔음</strong>
# </div>
# </a>
# </div>
# <div class="rcontimg_box" style="display:none;">
# <a class="inner logClass" depth1="rightframe" depth2="realtimebest" href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327283">
# <span class="img_box">
# <img alt="" src="https://dccdn11.dcinside.co.kr/viewimage.php?id=29bed223f6c6&amp;no=24b0d769e1d32ca73de882fa11d028311f815e76427ca587580740d4dcef76967833816e8176d545aa6432c967307a1e88f621e05d452e8da54b1ee593758252eb756b54421779e113b8358dd249a118653b47ce10d57689b76c6a38fae156312f7d7c160df081c56d9fbb3b2625" style="{" top=""/>
# </span>
# <div class="txt_box">
# <strong>신입 승무원 시절 겪은 태움 문화</strong>
# </div>
# </a>
# </div>
# </div>
# <ul class="txt">
# <li><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327251">24년 5월 전일본공수 NH 89 도쿄 하네다 → 이시가키 탑승후기</a></li>
# <li><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327269">싱글벙글 성시경 vs 백종원 자존심 강한 두 기존쎄의 대화</a></li>
# <li><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327390">공인중개사 사칭해 비번알아낸 사기꾼들</a></li>
# <li><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327414">매우 충격적인 내장지방 빼는법</a></li>
# <li><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327299">싱글벙글 부부싸움하는 집안의 자녀 심정 </a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327323">日궁내청 직원이 일왕 재산 빼돌리다 걸려... 전대미문의 사건에 발칵!</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327396">GPT-4o:사이버렉카 사탄냥이</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327420">아이 핑계대고 이혼 못했다는 말 웃기네…</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327387">비싼 무선 이어폰 안사게 된 이유.jpg</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327329">한덕수 러브콜에도 뜨뜻미지근... '단일화 기싸움' 시작</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327378">'김건희 선물'이 YTN 인수 뇌물? YTN지부 "유진은 뭘 바쳤나"</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327287">바다에서 로또 맞은 예멘 어부들.. jpg</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327354">日, 수돗물 마시고 집단 식중독... 무너진 안전신화?!</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327263">소방청 윤성빈 밈 근황 ㅋㅋㅋ</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327319">초스피드로 이재명 재판 진행하는 서울고법.jpg</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327295">"정규직이나 비정규직이나"...실제 월급 받아보니 '어휴'</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327337">오싹오싹 교직원의 실수 때문에 대학 합격 취소된 A양</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327309">싱글벙글 의외로 맛있다는 혐오식품</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327357">오싹오싹 겉모습만 보고 판단하면 안되는 상어언냐들</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327363">뿌강점기에도 쉴드가 안됐던 백종원식 야스리 사용법</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327335">이재명 '선거법 사건' 파기환송심 5월15일..ㄷㄷ</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327277">故 강지용 아내, 시母와 문자 내용 공개 "거짓말 그냥 안 넘어가"</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327360">슬픔슬픔…챗 GPT가 말하는 사람 구실 커트라인 학벌</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327281">'해킹 피해에'…가상화폐 위믹스, 국내 거래소서 상장 폐지</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327279">최신 다이어트 과학에서 '혈당 스파이크'가 중요한 이유</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327271">"너무 비싸" 금값 폭등에 종잇장 반지까지, 1위는 '현금 10만 원'</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327384">日, 끊이지 않는 온천 민폐... 대중탕에 입욕제 풀어놓기까지</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327297">47세녀 시험관 계속하면 집착이라고요?</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327305">남고생이 전생에 성녀였나봄. manhwa</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327257">결혼 준비중인 여친이 30살도 더 많은 할배랑 바람을 피웠어...ㄷㄷ</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327402">제사 준비하는 어머니에게 식용유랑 간장을 사드렸다가 와이프한테 혼난블라남</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327411">장문) 스팀 전쟁 게임 축제 기념 밀리터리 게임들 추천 해봄</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327405">폰카 사진 (20장)</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327317">안싱글벙글 중국산 치킨</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327311">체코 : "한국이 수주한 원전 사업, 한국 금융지원(덤핑) 없다."</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327331">숨 쉬기 위해서 항상 움직여야 한다는 참치</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327255">"걱정마세요"활동 보호사의 두얼굴...CCTV 본 가족 '피눈물'</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327369">나고야 도장깨기 여행 1일차 - 나고야성, 나고야역</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327307">中, 시진핑 지시도 소용 없었다... 연이은 화재 폭발로 사상자 속출</a></li>
# <li style="display:none;"><a href="https://gall.dcinside.com/board/view/?id=dcbest&amp;no=327348">미술 전공했다는 고윤정이 그린 조세호, 유재석.jpg</a></li>
# </ul>
# </div>
# </div>
# </article>
# <!--  //실시간 베스트 -->
# <!-- 뉴스 -->
# <article>
# <div class="content_box r_dcmedia">
# <header>
# <h3 class="tit newsTab"><a href="javascript:mediaTabMove('news');">뉴스</a></h3>
# <h3 class="tit mediaTab"><a href="javascript:mediaTabMove('media');">디시미디어</a></h3>
# <h3 class="tit issueTab"><a href="javascript:mediaTabMove('issue');">디시이슈</a></h3>
# <div class="pageing_box">
# <div class="page_num">
# <strong class="now_num newsNum">1</strong>/<span class="total_num newsTotal" id="newsTotal">2</span>
# </div>
# <button class="btn_blueprev" id="news_prev" type="button"><span class="blind">이전</span><em class="sp_img icon_blueprev"></em></button>
# <button class="btn_bluenext on" id="news_next" type="button"><span class="blind">다음</span><em class="sp_img icon_bluenext"></em></button>
# </div>
# </header>
# <div class="rcont_imgtxt_box r_news_box">
# <div class="img">
# <script id="newsImg-tmpl" type="text/x-jquery-tmpl">
#         	<div class="rcontimg_box">
#             	<a class="inner" href="${url}" target="_blank">
#                 	<span class="img_box">
#                     	<img src="${thumb}" alt="">
#                     </span>
#                     <div class="txt_box">
#                     	<strong>${title}</strong>
#                     </div>
#                  </a>
#              </div>
#         </script>
# </div>
# <ul class="txt">
# <script id="newsTxt-tmpl" type="text/x-jquery-tmpl">
#          	<li><a href="${url}" target="_blank">${title}</a></li>
#          </script>
# </ul>
# </div>
# <div class="rcont_imgtxt_box r_media_box" style="display:none;">
# <div class="img clear">
# <script id="mediaImg-tmpl" type="text/x-jquery-tmpl">
# 				<div class="rcontimg_box">
# 					<a class="inner" href="${link}" target = "${link.indexOf('https://gall.dcinside.com') === 0 ? '_self' : '_blank'}">
# 						<span class="img_box">
# 						<img src="${thumb_img}" alt="">
# 						</span>
# 						<div class="txt_box">
# 							<strong>${title}</strong>
# 						</div>
# 					</a>
# 				</div>
#                 </script>
# </div>
# <ul class="txt">
# <script id="mediaTxt-tmpl" type="text/x-jquery-tmpl">
# 				<li><a href="${link}" target = "${link.indexOf('https://gall.dcinside.com') === 0 ? '_self' : '_blank'}">${title}</a></li>
# 				</script>
# </ul>
# </div>
# <div class="rcont_imgtxt_box dcissue r_issue_box" style="display:none;">
# <div class="img clear">
# <script id="issueImg-tmpl" type="text/x-jquery-tmpl">
# 				<div class="rcontimg_box">
# 					<a class="inner" href="${url}" target = "_blank">
# 						<span class="img_box">
# 						<img src="${dc_img}" alt="">
# 						</span>
# 						<div class="txt_box">
#                             <span class="ranking blue">${rank}</span>
# 							<strong>${title}</strong>
# 						</div>
# 					</a>
# 				</div>
#                 </script>
# </div>
# <ul class="txt">
# <script id="issueTxt-tmpl" type="text/x-jquery-tmpl">
# 				<li>
#                     <a href="${url}" target = "_blank">
#                     <span class="ranking blue">${rank}</span>
#                     ${title}
#                     </a>
#                 </li>
# 				</script>
# </ul>
# </div>
# </div>
# </article>
# <!-- //뉴스 -->
# <!-- 개념글 -->
# <article>
# <div class="content_box r_recommend">
# <header>
# <script id="recomTit-tmpl" type="text/x-jquery-tmpl">
# 		<h3 class="tit"><a href="${url}">개념글 <span class="sub">[<em>${gall_name} 갤러리</em>]</span></a></h3>
# 	  </script>
# <div class="pageing_box">
# <div class="page_num">
# <strong class="now_num recomNum">1</strong>/<span class="total_num recomTotal">3</span>
# </div>
# <button class="btn_blueprev" id="recom_prev" type="button"><span class="blind">이전</span><em class="sp_img icon_blueprev"></em></button>
# <button class="btn_bluenext on" id="recom_next" type="button"><span class="blind">다음</span><em class="sp_img icon_bluenext"></em></button>
# </div>
# </header>
# <ul class="rcont_list">
# <script id="recomList-tmpl" type="text/x-jquery-tmpl">
# 		<li><a href="${url}">${title}</a></li>
# 	  </script>
# </ul>
# </div>
# </article>
# <!-- //개념글 -->
# </section>
# <!-- right_content -->
# </div>
# </main>
# <!-- 하단 -->
# <footer class="dcfoot type1">
# <div class="info_policy">
# <a href="https://www.dcinside.com/company">회사소개</a>
# <a href="https://www.dcinside.com/company#alliance">제휴안내</a>
# <a href="https://nstatic.dcinside.com/dc/dcad/w/index.html">광고안내</a>
# <a href="https://nstatic.dcinside.com/dc/w/policy/policy_index.html">이용약관</a>
# <a href="https://nstatic.dcinside.com/dc/w/policy/privacy_index.html"><b>개인정보처리방침</b></a>
# <a href="https://nstatic.dcinside.com/dc/w/policy/youth_policy.html">청소년보호정책</a>
# </div>
# <div class="copyright">Copyright ⓒ 1999 - 2025 dcinside. All rights reserved.</div>
# </footer>
# <!-- //하단 -->
# </div><!--//id:top-->
# <input id="s_keyword" type="hidden" value="편의점"/>
# <script src="https://ssl.pstatic.net/adimg3.search/adpost/js/adpost_show_ads_v2.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# var s_keyword = $('#s_keyword').val();
#
# function handle_naver_ads_response(response) {
# 	if(typeof(response['error']) == 'undefined' && response['ads']['length']) {
# 		$('.ad_premium *').remove();
#
# 		var html = '<div class="clear">' +
# 				   '<h3 class="fl">파워링크 <span class="adicon sp_img"><em class="blind">광고</em></span></h3>' +
# 				   '<a href="https://saedu.naver.com/adbiz/searchad/intro.nhn" target="_blank" class="fr link_upinfo">등록안내</a>' +
# 				   '</div>' +
# 				   '<ul class="pwlink_list abundle">';
#
# 		var patt = eval('/'+ s_keyword +'/g');
#
# 		for(var i in response['ads']) {
# 		 	ad_array = response['ads'][i];
# 			var desc = new String(ad_array['description']);
# 		 	html += '<li>'+
# 					'<a href="'+ ad_array['clickUrl'] + '" target="_blank">' +
# 		 			'<span class="tit_txt">'+ ad_array['headline'] +'</span>'+
# 		 			'<span class="link_txt">'+ ad_array['displayUrl'] +'</span>'+
# 		 			'<p class="link_dsc_txt">'+ desc.replace(patt, '<strong>'+ s_keyword +'</strong>') +'</p>'+
# 					'</a>'+
# 		 			'</li>';
# 		}
#
# 		html += '</ul>';
#
# 		$('.ad_premium').append(html).show();
# 	}
#
# 	if($('.ad_premium').index() >= 0) {
# 		if($('.ad_premium').html().trim()) {
# 			$('.ad_premium').show();
# 		}
# 		else {
# 			$('.ad_premium').remove();
# 		}
# 	}
# }
#
# //<![CDATA[
# NAVER_ADPOST_V2({
# 	channel: "dcinside.ch1",
# 	pageSize: 3,
# 	url: location.href,
# 	query: s_keyword
# });
# //]]>
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-5149721-4"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-5149721-4');
#
#   var f_u_no = '';
# </script>
# <!-- g4a 구글애널리틱스 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-V46B0SHSY7"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'G-V46B0SHSY7');
# </script>
# </body>
# </html>

# %%
title_soup = soup.select('a.tit_txt')

titles = [title.text for title in title_soup]

titles[:5]
# Out:
# ['이거코리안',
#  '크레인 부기사 한달하고 때려치움....굴삭기 경력쌓으러 런한다..',
#  '나 이타백매고 동네편의점도 잘만 가는데',
#  '편의점 식탁 저거 탐나는데????',
#  '이세돌빵 나오면 동네 편의점 뒤졌다 봐야지']

# %%
def find_titles(soup): 
    """게시물 제목을 수집"""
    title_soup = soup.select('a.tit_txt')
    titles = [title.text for title in title_soup]
    return titles

titles = find_titles(soup)
titles[:-2]
# Out:
# ['이거코리안',
#  '크레인 부기사 한달하고 때려치움....굴삭기 경력쌓으러 런한다..',
#  '나 이타백매고 동네편의점도 잘만 가는데',
#  '편의점 식탁 저거 탐나는데????',
#  '이세돌빵 나오면 동네 편의점 뒤졌다 봐야지',
#  '주휴수당 검색해보는데 편의점 점주들 겁나 웃기네',
#  '생산직 갤러리 공식 채팅방 오세요',
#  '중소기업 갤러리 공식 채팅방 오세요',
#  'KT 데쉐에 쓸 유심 찾다가 질문글 신기한거 많은듯...',
#  '아오 비 오는데 편의점을 왜 쳐 오는 거야',
#  '편의점 알바하면서 견적 짜봄',
#  '오늘 스즈메랑 문단속이 아니라',
#  '헬똥 석촌호수 근처 살면서',
#  '편의점에 조각 케익사러갈까',
#  '내일은 편의점 가서 빵이나 먹어야지',
#  '편의점가면 꼭 사는 것',
#  '노동청의 힘을 계승한 자는',
#  '마츠나가 방금 라방ㅋㅋ',
#  '탈갤.',
#  '편의점 데려갔는데 뭐 살지 한참 고민하는 여자는 걸러라',
#  '문수구장 주변에 아무것도 없던데',
#  '치킨먹기는 글렀고',
#  '나 진심으로 궁금한데 너네들 뭐하고 놀아?']

# %%
content_soup = soup.select('p.link_dsc_txt')

contents = [content.text for content in content_soup]

contents[:10]
# Out:
# ['행복한 하루 보내세요 편의점 갤러리 나링',
#  '편의점2025.05.03 00:19',
#  '거 보고 맘접기로 함. 나중에 내가 기사달고도 평생 저렇게 땀흘리면서 세팅하고 철수할 자신이 없다.. 편의점만 하다가 현장일하니 의욕으론 1주일 밖에 못버티겠더라 내가 책임질 식구들이 있다? -> 식구들만...',
#  '크레인2025.05.03 00:18',
#  '오타쿠인거 온동네사람이 다 알겠다고 엄니가 재밌어해',
#  '우마무스메 프리티 더비2025.05.03 00:17',
#  '??',
#  '기타 국내 드라마2025.05.03 00:16',
#  '',
#  '이세계아이돌2025.05.03 00:15']

# %%
def find_content(soup): 
    """게시물 본문과 게시판&작성일을 수집"""
    content_soup = soup.select('p.link_dsc_txt')
    contents = [content.text for content in content_soup]

    contents_text = []                           # 게시물 본문만 수집 
    etc = []                                     # 그 외 나머지 (게시판명과 작성일을 수집) 
    for idx, content in enumerate(contents):     # enumerate함수로 하나씩 조건문으로 추출 (0, '첫번째값'), (1, '두번째값') 이렇게 추출됨 
        if idx % 2 == 0 :                        # 인덱스를 2로 나누어서 0이 된다면 == 짝수라면 게시물 본문에 수집 
            contents_text.append(content)        
        else:                                    # 인덱스를 2로 나누어서 0이 안된다면 == 홀수라면 그 외 나머지 (게시판명과 작성일)에 수집 
            etc.append(content) 
    return contents_text, etc                    # 이렇게 게시물본문 / 게시판&작성일로 나누어서 별개로 저장 

contents_text, etc = find_content(soup) 

print(contents_text[:6])
print(etc[:6])
# Out:
# ['행복한 하루 보내세요 편의점 갤러리 나링', '거 보고 맘접기로 함. 나중에 내가 기사달고도 평생 저렇게 땀흘리면서 세팅하고 철수할 자신이 없다.. 편의점만 하다가 현장일하니 의욕으론 1주일 밖에 못버티겠더라 내가 책임질 식구들이 있다? -> 식구들만...', '오타쿠인거 온동네사람이 다 알겠다고 엄니가 재밌어해', '??', '', '15시간 이상 근무시켜놓고 주휴수당을 요구하는게 엄청 나쁜짓이라고 생각하는건가ㅋㅋ']
# ['편의점2025.05.03 00:19', '크레인2025.05.03 00:18', '우마무스메 프리티 더비2025.05.03 00:17', '기타 국내 드라마2025.05.03 00:16', '이세계아이돌2025.05.03 00:15', '아이리 칸나2025.05.03 00:14']

# %%
titles = []
contents = []
etcs = []

for i in range(1, 101) : 
    print("100페이지 중 현재 {}페이지".format(i)) 

    response = requests.get(url.format(i))

    html = response.text

    soup = BeautifulSoup(html, 'lxml')

    title = find_titles(soup)

    content, etc = find_content(soup)

    titles.extend(title) 

    contents.extend(content)

    etcs.extend(etc)

    time.sleep(1)
# Out:
# 100페이지 중 현재 1페이지
# 100페이지 중 현재 2페이지
# 100페이지 중 현재 3페이지
# 100페이지 중 현재 4페이지
# 100페이지 중 현재 5페이지
# 100페이지 중 현재 6페이지
# 100페이지 중 현재 7페이지
# 100페이지 중 현재 8페이지
# 100페이지 중 현재 9페이지
# 100페이지 중 현재 10페이지
# 100페이지 중 현재 11페이지
# 100페이지 중 현재 12페이지
# 100페이지 중 현재 13페이지
# 100페이지 중 현재 14페이지
# 100페이지 중 현재 15페이지
# 100페이지 중 현재 16페이지
# 100페이지 중 현재 17페이지
# 100페이지 중 현재 18페이지
# 100페이지 중 현재 19페이지
# 100페이지 중 현재 20페이지
# 100페이지 중 현재 21페이지
# 100페이지 중 현재 22페이지
# 100페이지 중 현재 23페이지
# 100페이지 중 현재 24페이지
# 100페이지 중 현재 25페이지
# 100페이지 중 현재 26페이지
# 100페이지 중 현재 27페이지
# 100페이지 중 현재 28페이지
# 100페이지 중 현재 29페이지
# 100페이지 중 현재 30페이지
# 100페이지 중 현재 31페이지
# 100페이지 중 현재 32페이지
# 100페이지 중 현재 33페이지
# 100페이지 중 현재 34페이지
# 100페이지 중 현재 35페이지
# 100페이지 중 현재 36페이지
# 100페이지 중 현재 37페이지
# 100페이지 중 현재 38페이지
# 100페이지 중 현재 39페이지
# 100페이지 중 현재 40페이지
# 100페이지 중 현재 41페이지
# 100페이지 중 현재 42페이지
# 100페이지 중 현재 43페이지
# 100페이지 중 현재 44페이지
# 100페이지 중 현재 45페이지
# 100페이지 중 현재 46페이지
# 100페이지 중 현재 47페이지
# 100페이지 중 현재 48페이지
# 100페이지 중 현재 49페이지
# 100페이지 중 현재 50페이지
# 100페이지 중 현재 51페이지
# 100페이지 중 현재 52페이지
# 100페이지 중 현재 53페이지
# 100페이지 중 현재 54페이지
# 100페이지 중 현재 55페이지
# 100페이지 중 현재 56페이지
# 100페이지 중 현재 57페이지
# 100페이지 중 현재 58페이지
# 100페이지 중 현재 59페이지
# 100페이지 중 현재 60페이지
# 100페이지 중 현재 61페이지
# 100페이지 중 현재 62페이지
# 100페이지 중 현재 63페이지
# 100페이지 중 현재 64페이지
# 100페이지 중 현재 65페이지
# 100페이지 중 현재 66페이지
# 100페이지 중 현재 67페이지
# 100페이지 중 현재 68페이지
# 100페이지 중 현재 69페이지
# 100페이지 중 현재 70페이지
# 100페이지 중 현재 71페이지
# 100페이지 중 현재 72페이지
# 100페이지 중 현재 73페이지
# 100페이지 중 현재 74페이지
# 100페이지 중 현재 75페이지
# 100페이지 중 현재 76페이지
# 100페이지 중 현재 77페이지
# 100페이지 중 현재 78페이지
# 100페이지 중 현재 79페이지
# 100페이지 중 현재 80페이지
# 100페이지 중 현재 81페이지
# 100페이지 중 현재 82페이지
# 100페이지 중 현재 83페이지
# 100페이지 중 현재 84페이지
# 100페이지 중 현재 85페이지
# 100페이지 중 현재 86페이지
# 100페이지 중 현재 87페이지
# 100페이지 중 현재 88페이지
# 100페이지 중 현재 89페이지
# 100페이지 중 현재 90페이지
# 100페이지 중 현재 91페이지
# 100페이지 중 현재 92페이지
# 100페이지 중 현재 93페이지
# 100페이지 중 현재 94페이지
# 100페이지 중 현재 95페이지
# 100페이지 중 현재 96페이지
# 100페이지 중 현재 97페이지
# 100페이지 중 현재 98페이지
# 100페이지 중 현재 99페이지
# 100페이지 중 현재 100페이지

# %%
titles[0:4]
# Out:
# ['내가 잘못한거냐? 편돌이들 들어와봐라',
#  '솔직히 공부해서 교도관 하느니',
#  '준스톤 이어원 관람객에 2030이 적은 이유',
#  '[팬아트] 무작정 올리고 보는 팬아트 + 간단리뷰 (13탄)']

# %%
contents[0:4]
# Out:
# ['편의점 테이블에서 닭가슴살 먹는데 반대편 의자에 발 올리고 먹음 아무도 없었으니까 ㅇㅇ 근데 알바가 발 낼려달라는거야 의자 더러워진다고 ㅋㅋㅋㅋ 내가 등산해서 신발 좀 더러웠거든 근데 그냥 듣는척도 안...',
#  '배달이나 편의점 알바가 나은듯 좀 위험해도 오토바이 타고 400 500벌거나 교도간보다 안전하게 편돌이 최저시급 댕겨도 월급 똑같음',
#  '펨코가 히키 본진이라 극장은 커녕 편의점 다녀오기도 벅참 - dc official App',
#  '덜 아플(?) 거라고 생각하기도 했고 설아 디자인이 이뻐서 설아 고름. 6, 7. 편의점의 비밀 메뉴 : 박아린, 신서희 - 편의점 알바를 하는 마왕이랑 공사판 노가다를 뛰는 용사라는 참신한 컨셉에서부터 재밌던...']

# %%
etcs[0:4]
# Out:
# ['편의점2025.04.27 15:37',
#  '교정직2025.04.27 15:37',
#  '중도정치2025.04.27 15:36',
#  '뤼튼2025.04.27 15:35']

# %%
df = pd.DataFrame({
    "게시물제목" : titles, 
    "내용" : contents, 
    "기타 정보" : etcs
})

df
# Out:
#                                   게시물제목  \
# 0                  내가 잘못한거냐? 편돌이들 들어와봐라
# 1                      솔직히 공부해서 교도관 하느니
# 2              준스톤 이어원 관람객에 2030이 적은 이유
# 3     [팬아트] 무작정 올리고 보는 팬아트 + 간단리뷰 (13탄)
# 4                  편의점 도시락으로 김밥 싸먹어도 될듯
# ...                                 ...
# 2495              룩 아웃사이드) 이러면 한패쪽 버근가?
# 2496        진짜 빛 안들어오는 반지하 월세방 편부모 가정같네
# 2497                         일본 처음 와보는데
# 2498             쿠팡 다니는 건 진짜 생각 없는 게 맞다
# 2499               일찍 일어나서 편의점에 아침 먹으러감
#
#                                                      내용  \
# 0     편의점 테이블에서 닭가슴살 먹는데 반대편 의자에 발 올리고 먹음 아무도 없었으니까 ...
# 1     배달이나 편의점 알바가 나은듯 좀 위험해도 오토바이 타고 400 500벌거나 교도간...
# 2     펨코가 히키 본진이라 극장은 커녕 편의점 다녀오기도 벅참 - dc official App
# 3     덜 아플(?) 거라고 생각하기도 했고 설아 디자인이 이뻐서 설아 고름. 6, 7. ...
# 4                                 내가 왜 그동안 이 생각을 못했지 ??
# ...                                                 ...
# 2495  편의점지네랑 싸우고나서 항상 이화면에서 안넘어가짐 1회차때는 0.6버전으로해서 이상...
# 2496  엄마가 아픈 몸에 편의점 알바 뛰다가 폐기 들고 왔는데 집어던지는 애새끼 같은 미정...
# 2497  편의점에 만화책 파는 거 엄청 신기하당 유명한 거 많았지만 100그녀는 안 보이더라...
# 2498  집 앞 편의점을 가도 시급이 똑같다 그냥 어떤 알바를 해도 쿠팡만큼 번다 출퇴시간 ...
# 2499                               아침은 GS25 치즈독과 몬스터제로임
#
#                          기타 정보
# 0          편의점2025.04.27 15:37
# 1          교정직2025.04.27 15:37
# 2         중도정치2025.04.27 15:36
# 3           뤼튼2025.04.27 15:35
# 4       자취, 독거2025.04.27 15:34
# ...                        ...
# 2495      인디게임2025.04.24 07:54
# 2496     미국 정치2025.04.24 07:51
# 2497  100명의 여친2025.04.24 07:49
# 2498     아르바이트2025.04.24 07:36
# 2499    새로운보수당2025.04.24 07:34
#
# [2500 rows x 3 columns]

# %%
import re 

######## 결과 ######## 번호 추출 결과 : 010-1234-5678 

phone_number = "안녕하세요. 제 연락처는 010-1234-5678 입니다! "

pattern_number = r"\d{3}-\d{4}-\d{4}"

number = re.search(pattern_number, phone_number)

print("번호 추출 결과 : ", number.group())
# Out:
# 번호 추출 결과 :  010-1234-5678

# %%
import re 

# 텍스트만 추출하라 

kor_eng_text = "'안녕하세요'는 영어로 Hello 인가요?"

kor_pattern = '[가-힣]+'

kor = re.compile(kor_pattern).findall(kor_eng_text)    

print("추출 1단계 : ", kor) 
print("추출 2단계 : ", " ".join(kor))
print("추출 3단계 : ", "".join(kor))
# Out:
# 추출 1단계 :  ['안녕하세요', '는', '영어로', '인가요']
# 추출 2단계 :  안녕하세요 는 영어로 인가요
# 추출 3단계 :  안녕하세요는영어로인가요

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   게시물제목   2500 non-null   object
#  1   내용      2500 non-null   object
#  2   기타 정보   2500 non-null   object
# dtypes: object(3)
# memory usage: 58.7+ KB

# %%
df.head()
# Out:
#                                게시물제목  \
# 0               내가 잘못한거냐? 편돌이들 들어와봐라
# 1                   솔직히 공부해서 교도관 하느니
# 2           준스톤 이어원 관람객에 2030이 적은 이유
# 3  [팬아트] 무작정 올리고 보는 팬아트 + 간단리뷰 (13탄)
# 4               편의점 도시락으로 김밥 싸먹어도 될듯
#
#                                                   내용                   기타 정보
# 0  편의점 테이블에서 닭가슴살 먹는데 반대편 의자에 발 올리고 먹음 아무도 없었으니까 ...     편의점2025.04.27 15:37
# 1  배달이나 편의점 알바가 나은듯 좀 위험해도 오토바이 타고 400 500벌거나 교도간...     교정직2025.04.27 15:37
# 2  펨코가 히키 본진이라 극장은 커녕 편의점 다녀오기도 벅참 - dc official App    중도정치2025.04.27 15:36
# 3  덜 아플(?) 거라고 생각하기도 했고 설아 디자인이 이뻐서 설아 고름. 6, 7. ...      뤼튼2025.04.27 15:35
# 4                              내가 왜 그동안 이 생각을 못했지 ??  자취, 독거2025.04.27 15:34

# %%
#         편의점2025.04.27 15:37 
#             ---------- 날짜만 빼내본다. 

import re 

etc_info = "편의점2025.04.27 15:37"

pattern = r"\d{4}.\d+.\d+"

result = re.search(pattern, etc_info) 

date = result.group()

print("원래데이터 : ", etc_info)
print("정규표현식 처리 후 : ", date)
# Out:
# 원래데이터 :  편의점2025.04.27 15:37
# 정규표현식 처리 후 :  2025.04.27

# %%
#         편의점2025.04.27 15:37 
#                         ---- 시간만 빼내본다. 

import re 

time_info = "편의점2025.04.27 15:37"

time_pattern = r"\d+:\d+"

time_result = re.search(time_pattern, time_info) 

time = time_result.group()

print("원래데이터 : ", time_info)
print("정규표현식 처리 후 : ", time)
# Out:
# 원래데이터 :  편의점2025.04.27 15:37
# 정규표현식 처리 후 :  15:37

# %%
def find_date(text) : 
    """날짜만 찾는다"""
    pattern = r"\d+.\d+.\d+"
    result = re.search(pattern, text) 
    date = result.group()
    return date 

def find_time(text) : 
    """시간만 찾는다"""
    pattern = r"\d+:\d+"
    result = re.search(pattern, text)
    time = result.group()
    return time 

############# test 

text = "중도정치2025.04.27 15:36"
print(find_date(text=text))
print(find_time(text=text))
# Out:
# 2025.04.27
# 15:36

# %%
df['날짜'] = df['기타 정보'].apply(lambda x:find_date(x))
df['작성시간'] = df['기타 정보'].apply(lambda x:find_time(x))
df
# Out:
#                                   게시물제목  \
# 0                  내가 잘못한거냐? 편돌이들 들어와봐라
# 1                      솔직히 공부해서 교도관 하느니
# 2              준스톤 이어원 관람객에 2030이 적은 이유
# 3     [팬아트] 무작정 올리고 보는 팬아트 + 간단리뷰 (13탄)
# 4                  편의점 도시락으로 김밥 싸먹어도 될듯
# ...                                 ...
# 2495              룩 아웃사이드) 이러면 한패쪽 버근가?
# 2496        진짜 빛 안들어오는 반지하 월세방 편부모 가정같네
# 2497                         일본 처음 와보는데
# 2498             쿠팡 다니는 건 진짜 생각 없는 게 맞다
# 2499               일찍 일어나서 편의점에 아침 먹으러감
#
#                                                      내용  \
# 0     편의점 테이블에서 닭가슴살 먹는데 반대편 의자에 발 올리고 먹음 아무도 없었으니까 ...
# 1     배달이나 편의점 알바가 나은듯 좀 위험해도 오토바이 타고 400 500벌거나 교도간...
# 2     펨코가 히키 본진이라 극장은 커녕 편의점 다녀오기도 벅참 - dc official App
# 3     덜 아플(?) 거라고 생각하기도 했고 설아 디자인이 이뻐서 설아 고름. 6, 7. ...
# 4                                 내가 왜 그동안 이 생각을 못했지 ??
# ...                                                 ...
# 2495  편의점지네랑 싸우고나서 항상 이화면에서 안넘어가짐 1회차때는 0.6버전으로해서 이상...
# 2496  엄마가 아픈 몸에 편의점 알바 뛰다가 폐기 들고 왔는데 집어던지는 애새끼 같은 미정...
# 2497  편의점에 만화책 파는 거 엄청 신기하당 유명한 거 많았지만 100그녀는 안 보이더라...
# 2498  집 앞 편의점을 가도 시급이 똑같다 그냥 어떤 알바를 해도 쿠팡만큼 번다 출퇴시간 ...
# 2499                               아침은 GS25 치즈독과 몬스터제로임
#
#                          기타 정보          날짜   작성시간
# 0          편의점2025.04.27 15:37  2025.04.27  15:37
# 1          교정직2025.04.27 15:37  2025.04.27  15:37
# 2         중도정치2025.04.27 15:36  2025.04.27  15:36
# 3           뤼튼2025.04.27 15:35  2025.04.27  15:35
# 4       자취, 독거2025.04.27 15:34  2025.04.27  15:34
# ...                        ...         ...    ...
# 2495      인디게임2025.04.24 07:54  2025.04.24  07:54
# 2496     미국 정치2025.04.24 07:51  2025.04.24  07:51
# 2497  100명의 여친2025.04.24 07:49  2025.04.24  07:49
# 2498     아르바이트2025.04.24 07:36  2025.04.24  07:36
# 2499    새로운보수당2025.04.24 07:34  2025.04.24  07:34
#
# [2500 rows x 5 columns]

# %%
# 2025.04.27문자형)에서 날짜형으로 변환 ---> 요일을 나타내는 번호로 변환 ---> 요일만 추출하는 함수 

###################################### 문자형(str)에서 날짜형(datetime)으로 변경 

from dateutil.parser import parse

date = "2025.04.27"            # str 
dateinfo = parse(date)         # datetime 

print(dateinfo.year)
print(dateinfo.month)
print(dateinfo.day)

###################################### 요일을 나타내는 번호로 변환

import calendar 

calendar.weekday(dateinfo.year, dateinfo.month, dateinfo.day)

# 0 월요일  
# 1 화요일 
# 2 수요일
# 3 목요일
# 4 금요일
# 5 토요일
# 6 일요일

###################################### 요일만 추출하는 함수

def find_day(date): 
    """요일 정보를 반환한다"""
    try : 
        dateinfo = parse(date)

        days = ['월요일','화요일','수요일','목요일','금요일','토요일','일요일']
        day = days[calendar.weekday(dateinfo.year, dateinfo.month, dateinfo.day)]
        return day 
        
    except:                 # 이걸 해줘야 에러 발생시, 코드 실행 중지되지 않고 알수없음으로 반환해줌 
        return "알수없음" 

print(find_day(date="2025.04.27"))
print(find_day(date="2025.04.26"))
# Out:
# 2025
# 4
# 27
# 일요일
# 토요일

# %%
df['요일'] = df['날짜'].apply(lambda x:find_day(x))
df['시간대'] = df['작성시간'].apply(lambda x:x.split(":")[0])
df.sample(5)
# Out:
#                       게시물제목  \
# 1903                     민짜
# 2044        테숏새끼들 오늘 소주마시냐?
# 2126   편의점 알바가 장얘찬보다 스펙 좋음.
# 1043  편의점 알바가 사람을 다 망치네요 ㅠㅠ
# 1283             와 밖에 웰케추움ㄷ
#
#                                                      내용  \
# 1903  하.. 나 민짜한테 담배 판 것 같음.. 편의점 알바 2주차인데 원래 난 민짜가오충...
# 2044        술집에서는 못마시겠노 편의점에서 노상이나까라 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 2126                                       진지하게 그게 더 나음
# 1043                             메론님도 그렇고 쿠로미님도 그렇고요 ㅠㅠ
# 1283    편의점 가려다 식겁하고 다시 들어와서 패딩 입음... - dc official App
#
#                       기타 정보          날짜   작성시간   요일 시간대
# 1903    편의점2025.04.25 05:49  2025.04.25  05:49  금요일  05
# 2044  미국 주식2025.04.24 23:13  2025.04.24  23:13  목요일  23
# 2126   중도보수2025.04.24 21:06  2025.04.24  21:06  목요일  21
# 1043     중도2025.04.26 11:55  2025.04.26  11:55  토요일  11
# 1283    판타지2025.04.26 01:50  2025.04.26  01:50  토요일  01

# %%
import os      # 폴더 또는 파일생성 또는 실행관련 기능이 담긴 os라이브러리 활용

SAVE_FILE_PATH = './'
if not os.path.exists(SAVE_FILE_PATH): 
    os.makedirs(SAVE_FILE_PATH)

df.to_excel(SAVE_FILE_PATH+'디씨_편의점게시물.xlsx', index=False)
df.to_csv(SAVE_FILE_PATH+'디씨_편의점게시물.csv', index=False)
